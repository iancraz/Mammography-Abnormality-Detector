# %% [markdown]
# # Mammography Abnormality Detector

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mias-mammography/Info.txt
# /kaggle/input/mias-mammography/all_mias_scans.h5
# /kaggle/input/mias-mammography/all-mias.tar.gz
# /kaggle/input/mias-mammography/all-mias/mdb152.pgm
# /kaggle/input/mias-mammography/all-mias/mdb088.pgm
# /kaggle/input/mias-mammography/all-mias/mdb113.pgm
# /kaggle/input/mias-mammography/all-mias/mdb182.pgm
# /kaggle/input/mias-mammography/all-mias/mdb239.pgm
# /kaggle/input/mias-mammography/all-mias/mdb066.pgm
# /kaggle/input/mias-mammography/all-mias/mdb220.pgm
# /kaggle/input/mias-mammography/all-mias/mdb292.pgm
# /kaggle/input/mias-mammography/all-mias/mdb286.pgm
# /kaggle/input/mias-mammography/all-mias/mdb103.pgm
# /kaggle/input/mias-mammography/all-mias/mdb194.pgm
# /kaggle/input/mias-mammography/all-mias/mdb275.pgm
# /kaggle/input/mias-mammography/all-mias/mdb060.pgm
# /kaggle/input/mias-mammography/all-mias/mdb067.pgm
# /kaggle/input/mias-mammography/all-mias/mdb023.pgm
# /kaggle/input/mias-mammography/all-mias/mdb073.pgm
# /kaggle/input/mias-mammography/all-mias/mdb307.pgm
# /kaggle/input/mias-mammography/all-mias/mdb233.pgm
# /kaggle/input/mias-mammography/all-mias/mdb154.pgm
# /kaggle/input/mias-mammography/all-mias/mdb141.pgm
# /kaggle/input/mias-mammography/all-mias/mdb065.pgm
# /kaggle/input/mias-mammography/all-mias/mdb084.pgm
# /kaggle/input/mias-mammography/all-mias/mdb097.pgm
# /kaggle/input/mias-mammography/all-mias/mdb235.pgm
# /kaggle/input/mias-mammography/all-mias/mdb183.pgm
# /kaggle/input/mias-mammography/all-mias/mdb056.pgm
# /kaggle/input/mias-mammography/all-mias/mdb156.pgm
# /kaggle/input/mias-mammography/all-mias/mdb218.pgm
# /kaggle/input/mias-mammography/all-mias/mdb048.pgm
# /kaggle/input/mias-mammography/all-mias/mdb270.pgm
# /kaggle/input/mias-mammography/all-mias/mdb093.pgm
# /kaggle/input/mias-mammography/all-mias/mdb184.pgm
# /kaggle/input/mias-mammography/all-mias/mdb178.pgm
# /kaggle/input/mias-mammography/all-mias/mdb069.pgm
# /kaggle/input/mias-mammography/all-mias/mdb039.pgm
# /kaggle/input/mias-mammography/all-mias/mdb026.pgm
# /kaggle/input/mias-mammography/all-mias/mdb037.pgm
# /kaggle/input/mias-mammography/all-mias/mdb297.pgm
# /kaggle/input/mias-mammography/all-mias/mdb146.pgm
# /kaggle/input/mias-mammography/all-mias/mdb300.pgm
# /kaggle/input/mias-mammography/all-mias/mdb255.pgm
# /kaggle/input/mias-mammography/all-mias/mdb050.pgm
# /kaggle/input/mias-mammography/all-mias/mdb042.pgm
# /kaggle/input/mias-mammography/all-mias/mdb217.pgm
# /kaggle/input/mias-mammography/all-mias/mdb008.pgm
# /kaggle/input/mias-mammography/all-mias/mdb309.pgm
# /kaggle/input/mias-mammography/all-mias/mdb229.pgm
# /kaggle/input/mias-mammography/all-mias/mdb010.pgm
# /kaggle/input/mias-mammography/all-mias/mdb020.pgm
# /kaggle/input/mias-mammography/all-mias/mdb281.pgm
# /kaggle/input/mias-mammography/all-mias/mdb316.pgm
# /kaggle/input/mias-mammography/all-mias/mdb018.pgm
# /kaggle/input/mias-mammography/all-mias/mdb256.pgm
# /kaggle/input/mias-mammography/all-mias/mdb004.pgm
# /kaggle/input/mias-mammography/all-mias/mdb131.pgm
# /kaggle/input/mias-mammography/all-mias/mdb196.pgm
# /kaggle/input/mias-mammography/all-mias/mdb043.pgm
# /kaggle/input/mias-mammography/all-mias/mdb277.pgm
# /kaggle/input/mias-mammography/all-mias/mdb002.pgm
# /kaggle/input/mias-mammography/all-mias/mdb041.pgm
# /kaggle/input/mias-mammography/all-mias/mdb259.pgm
# /kaggle/input/mias-mammography/all-mias/mdb273.pgm
# /kaggle/input/mias-mammography/all-mias/mdb191.pgm
# /kaggle/input/mias-mammography/all-mias/mdb145.pgm
# /kaggle/input/mias-mammography/all-mias/mdb101.pgm
# /kaggle/input/mias-mammography/all-mias/mdb047.pgm
# /kaggle/input/mias-mammography/all-mias/mdb170.pgm
# /kaggle/input/mias-mammography/all-mias/mdb193.pgm
# /kaggle/input/mias-mammography/all-mias/Licence.txt
# /kaggle/input/mias-mammography/all-mias/mdb321.pgm
# /kaggle/input/mias-mammography/all-mias/mdb177.pgm
# /kaggle/input/mias-mammography/all-mias/mdb176.pgm
# /kaggle/input/mias-mammography/all-mias/mdb271.pgm
# /kaggle/input/mias-mammography/all-mias/mdb094.pgm
# /kaggle/input/mias-mammography/all-mias/mdb105.pgm
# /kaggle/input/mias-mammography/all-mias/mdb133.pgm
# /kaggle/input/mias-mammography/all-mias/mdb144.pgm
# /kaggle/input/mias-mammography/all-mias/mdb301.pgm
# /kaggle/input/mias-mammography/all-mias/mdb030.pgm
# /kaggle/input/mias-mammography/all-mias/mdb295.pgm
# /kaggle/input/mias-mammography/all-mias/mdb238.pgm
# /kaggle/input/mias-mammography/all-mias/mdb162.pgm
# /kaggle/input/mias-mammography/all-mias/mdb059.pgm
# /kaggle/input/mias-mammography/all-mias/mdb219.pgm
# /kaggle/input/mias-mammography/all-mias/mdb007.pgm
# /kaggle/input/mias-mammography/all-mias/mdb246.pgm
# /kaggle/input/mias-mammography/all-mias/mdb172.pgm
# /kaggle/input/mias-mammography/all-mias/mdb260.pgm
# /kaggle/input/mias-mammography/all-mias/mdb027.pgm
# /kaggle/input/mias-mammography/all-mias/mdb245.pgm
# /kaggle/input/mias-mammography/all-mias/mdb223.pgm
# /kaggle/input/mias-mammography/all-mias/mdb254.pgm
# /kaggle/input/mias-mammography/all-mias/mdb185.pgm
# /kaggle/input/mias-mammography/all-mias/mdb044.pgm
# /kaggle/input/mias-mammography/all-mias/mdb206.pgm
# /kaggle/input/mias-mammography/all-mias/mdb104.pgm
# /kaggle/input/mias-mammography/all-mias/mdb135.pgm
# /kaggle/input/mias-mammography/all-mias/mdb052.pgm
# /kaggle/input/mias-mammography/all-mias/mdb031.pgm
# /kaggle/input/mias-mammography/all-mias/mdb278.pgm
# /kaggle/input/mias-mammography/all-mias/mdb173.pgm
# /kaggle/input/mias-mammography/all-mias/mdb011.pgm
# /kaggle/input/mias-mammography/all-mias/mdb167.pgm
# /kaggle/input/mias-mammography/all-mias/mdb305.pgm
# /kaggle/input/mias-mammography/all-mias/README
# /kaggle/input/mias-mammography/all-mias/mdb188.pgm
# /kaggle/input/mias-mammography/all-mias/mdb224.pgm
# /kaggle/input/mias-mammography/all-mias/mdb247.pgm
# /kaggle/input/mias-mammography/all-mias/mdb164.pgm
# /kaggle/input/mias-mammography/all-mias/mdb120.pgm
# /kaggle/input/mias-mammography/all-mias/mdb137.pgm
# /kaggle/input/mias-mammography/all-mias/mdb225.pgm
# /kaggle/input/mias-mammography/all-mias/mdb264.pgm
# /kaggle/input/mias-mammography/all-mias/mdb257.pgm
# /kaggle/input/mias-mammography/all-mias/mdb236.pgm
# /kaggle/input/mias-mammography/all-mias/mdb128.pgm
# /kaggle/input/mias-mammography/all-mias/mdb240.pgm
# /kaggle/input/mias-mammography/all-mias/mdb197.pgm
# /kaggle/input/mias-mammography/all-mias/mdb024.pgm
# /kaggle/input/mias-mammography/all-mias/mdb035.pgm
# /kaggle/input/mias-mammography/all-mias/mdb013.pgm
# /kaggle/input/mias-mammography/all-mias/mdb108.pgm
# /kaggle/input/mias-mammography/all-mias/mdb249.pgm
# /kaggle/input/mias-mammography/all-mias/mdb126.pgm
# /kaggle/input/mias-mammography/all-mias/mdb237.pgm
# /kaggle/input/mias-mammography/all-mias/mdb090.pgm
# /kaggle/input/mias-mammography/all-mias/mdb269.pgm
# /kaggle/input/mias-mammography/all-mias/mdb061.pgm
# /kaggle/input/mias-mammography/all-mias/mdb107.pgm
# /kaggle/input/mias-mammography/all-mias/mdb112.pgm
# /kaggle/input/mias-mammography/all-mias/mdb213.pgm
# /kaggle/input/mias-mammography/all-mias/mdb118.pgm
# /kaggle/input/mias-mammography/all-mias/mdb318.pgm
# /kaggle/input/mias-mammography/all-mias/mdb040.pgm
# /kaggle/input/mias-mammography/all-mias/mdb017.pgm
# /kaggle/input/mias-mammography/all-mias/mdb306.pgm
# /kaggle/input/mias-mammography/all-mias/mdb019.pgm
# /kaggle/input/mias-mammography/all-mias/mdb057.pgm
# /kaggle/input/mias-mammography/all-mias/mdb077.pgm
# /kaggle/input/mias-mammography/all-mias/mdb022.pgm
# /kaggle/input/mias-mammography/all-mias/mdb186.pgm
# /kaggle/input/mias-mammography/all-mias/mdb209.pgm
# /kaggle/input/mias-mammography/all-mias/mdb299.pgm
# /kaggle/input/mias-mammography/all-mias/mdb174.pgm
# /kaggle/input/mias-mammography/all-mias/mdb250.pgm
# /kaggle/input/mias-mammography/all-mias/mdb207.pgm
# /kaggle/input/mias-mammography/all-mias/mdb012.pgm
# /kaggle/input/mias-mammography/all-mias/mdb089.pgm
# /kaggle/input/mias-mammography/all-mias/mdb123.pgm
# /kaggle/input/mias-mammography/all-mias/mdb136.pgm
# /kaggle/input/mias-mammography/all-mias/mdb314.pgm
# /kaggle/input/mias-mammography/all-mias/mdb115.pgm
# /kaggle/input/mias-mammography/all-mias/mdb234.pgm
# /kaggle/input/mias-mammography/all-mias/mdb201.pgm
# /kaggle/input/mias-mammography/all-mias/mdb147.pgm
# /kaggle/input/mias-mammography/all-mias/mdb198.pgm
# /kaggle/input/mias-mammography/all-mias/mdb252.pgm
# /kaggle/input/mias-mammography/all-mias/mdb095.pgm
# /kaggle/input/mias-mammography/all-mias/mdb294.pgm
# /kaggle/input/mias-mammography/all-mias/mdb243.pgm
# /kaggle/input/mias-mammography/all-mias/mdb304.pgm
# /kaggle/input/mias-mammography/all-mias/mdb211.pgm
# /kaggle/input/mias-mammography/all-mias/mdb122.pgm
# /kaggle/input/mias-mammography/all-mias/mdb221.pgm
# /kaggle/input/mias-mammography/all-mias/mdb124.pgm
# /kaggle/input/mias-mammography/all-mias/mdb079.pgm
# /kaggle/input/mias-mammography/all-mias/mdb092.pgm
# /kaggle/input/mias-mammography/all-mias/mdb032.pgm
# /kaggle/input/mias-mammography/all-mias/mdb003.pgm
# /kaggle/input/mias-mammography/all-mias/mdb072.pgm
# /kaggle/input/mias-mammography/all-mias/mdb317.pgm
# /kaggle/input/mias-mammography/all-mias/mdb204.pgm
# /kaggle/input/mias-mammography/all-mias/mdb009.pgm
# /kaggle/input/mias-mammography/all-mias/mdb248.pgm
# /kaggle/input/mias-mammography/all-mias/mdb143.pgm
# /kaggle/input/mias-mammography/all-mias/mdb261.pgm
# /kaggle/input/mias-mammography/all-mias/mdb158.pgm
# /kaggle/input/mias-mammography/all-mias/mdb051.pgm
# /kaggle/input/mias-mammography/all-mias/mdb187.pgm
# /kaggle/input/mias-mammography/all-mias/mdb312.pgm
# /kaggle/input/mias-mammography/all-mias/mdb241.pgm
# /kaggle/input/mias-mammography/all-mias/mdb087.pgm
# /kaggle/input/mias-mammography/all-mias/mdb062.pgm
# /kaggle/input/mias-mammography/all-mias/mdb302.pgm
# /kaggle/input/mias-mammography/all-mias/mdb055.pgm
# /kaggle/input/mias-mammography/all-mias/mdb074.pgm
# /kaggle/input/mias-mammography/all-mias/mdb268.pgm
# /kaggle/input/mias-mammography/all-mias/Info.txt
# /kaggle/input/mias-mammography/all-mias/mdb098.pgm
# /kaggle/input/mias-mammography/all-mias/mdb100.pgm
# /kaggle/input/mias-mammography/all-mias/mdb161.pgm
# /kaggle/input/mias-mammography/all-mias/mdb033.pgm
# /kaggle/input/mias-mammography/all-mias/mdb014.pgm
# /kaggle/input/mias-mammography/all-mias/mdb222.pgm
# /kaggle/input/mias-mammography/all-mias/mdb025.pgm
# /kaggle/input/mias-mammography/all-mias/mdb175.pgm
# /kaggle/input/mias-mammography/all-mias/mdb284.pgm
# /kaggle/input/mias-mammography/all-mias/mdb189.pgm
# /kaggle/input/mias-mammography/all-mias/mdb125.pgm
# /kaggle/input/mias-mammography/all-mias/mdb127.pgm
# /kaggle/input/mias-mammography/all-mias/mdb265.pgm
# /kaggle/input/mias-mammography/all-mias/mdb258.pgm
# /kaggle/input/mias-mammography/all-mias/mdb091.pgm
# /kaggle/input/mias-mammography/all-mias/mdb138.pgm
# /kaggle/input/mias-mammography/all-mias/mdb205.pgm
# /kaggle/input/mias-mammography/all-mias/mdb308.pgm
# /kaggle/input/mias-mammography/all-mias/mdb266.pgm
# /kaggle/input/mias-mammography/all-mias/mdb106.pgm
# /kaggle/input/mias-mammography/all-mias/mdb160.pgm
# /kaggle/input/mias-mammography/all-mias/mdb166.pgm
# /kaggle/input/mias-mammography/all-mias/mdb251.pgm
# /kaggle/input/mias-mammography/all-mias/mdb282.pgm
# /kaggle/input/mias-mammography/all-mias/mdb085.pgm
# /kaggle/input/mias-mammography/all-mias/mdb190.pgm
# /kaggle/input/mias-mammography/all-mias/mdb116.pgm
# /kaggle/input/mias-mammography/all-mias/mdb063.pgm
# /kaggle/input/mias-mammography/all-mias/mdb045.pgm
# /kaggle/input/mias-mammography/all-mias/mdb078.pgm
# /kaggle/input/mias-mammography/all-mias/mdb280.pgm
# /kaggle/input/mias-mammography/all-mias/mdb071.pgm
# /kaggle/input/mias-mammography/all-mias/mdb053.pgm
# /kaggle/input/mias-mammography/all-mias/mdb086.pgm
# /kaggle/input/mias-mammography/all-mias/mdb083.pgm
# /kaggle/input/mias-mammography/all-mias/mdb303.pgm
# /kaggle/input/mias-mammography/all-mias/mdb029.pgm
# /kaggle/input/mias-mammography/all-mias/mdb148.pgm
# /kaggle/input/mias-mammography/all-mias/mdb096.pgm
# /kaggle/input/mias-mammography/all-mias/mdb036.pgm
# /kaggle/input/mias-mammography/all-mias/mdb320.pgm
# /kaggle/input/mias-mammography/all-mias/mdb168.pgm
# /kaggle/input/mias-mammography/all-mias/mdb319.pgm
# /kaggle/input/mias-mammography/all-mias/mdb134.pgm
# /kaggle/input/mias-mammography/all-mias/mdb272.pgm
# /kaggle/input/mias-mammography/all-mias/mdb202.pgm
# /kaggle/input/mias-mammography/all-mias/mdb001.pgm
# /kaggle/input/mias-mammography/all-mias/mdb311.pgm
# /kaggle/input/mias-mammography/all-mias/mdb253.pgm
# /kaggle/input/mias-mammography/all-mias/mdb021.pgm
# /kaggle/input/mias-mammography/all-mias/mdb068.pgm
# /kaggle/input/mias-mammography/all-mias/mdb179.pgm
# /kaggle/input/mias-mammography/all-mias/mdb157.pgm
# /kaggle/input/mias-mammography/all-mias/mdb114.pgm
# /kaggle/input/mias-mammography/all-mias/mdb070.pgm
# /kaggle/input/mias-mammography/all-mias/mdb165.pgm
# /kaggle/input/mias-mammography/all-mias/mdb132.pgm
# /kaggle/input/mias-mammography/all-mias/mdb298.pgm
# /kaggle/input/mias-mammography/all-mias/mdb142.pgm
# /kaggle/input/mias-mammography/all-mias/mdb082.pgm
# /kaggle/input/mias-mammography/all-mias/mdb296.pgm
# /kaggle/input/mias-mammography/all-mias/mdb006.pgm
# /kaggle/input/mias-mammography/all-mias/mdb199.pgm
# /kaggle/input/mias-mammography/all-mias/mdb150.pgm
# /kaggle/input/mias-mammography/all-mias/mdb102.pgm
# /kaggle/input/mias-mammography/all-mias/mdb058.pgm
# /kaggle/input/mias-mammography/all-mias/mdb109.pgm
# /kaggle/input/mias-mammography/all-mias/mdb038.pgm
# /kaggle/input/mias-mammography/all-mias/mdb119.pgm
# /kaggle/input/mias-mammography/all-mias/mdb076.pgm
# /kaggle/input/mias-mammography/all-mias/mdb195.pgm
# /kaggle/input/mias-mammography/all-mias/mdb169.pgm
# /kaggle/input/mias-mammography/all-mias/mdb287.pgm
# /kaggle/input/mias-mammography/all-mias/mdb313.pgm
# /kaggle/input/mias-mammography/all-mias/mdb046.pgm
# /kaggle/input/mias-mammography/all-mias/mdb200.pgm
# /kaggle/input/mias-mammography/all-mias/mdb315.pgm
# /kaggle/input/mias-mammography/all-mias/mdb180.pgm
# /kaggle/input/mias-mammography/all-mias/mdb064.pgm
# /kaggle/input/mias-mammography/all-mias/mdb262.pgm
# /kaggle/input/mias-mammography/all-mias/mdb230.pgm
# /kaggle/input/mias-mammography/all-mias/mdb192.pgm
# /kaggle/input/mias-mammography/all-mias/mdb153.pgm
# /kaggle/input/mias-mammography/all-mias/mdb276.pgm
# /kaggle/input/mias-mammography/all-mias/mdb232.pgm
# /kaggle/input/mias-mammography/all-mias/mdb288.pgm
# /kaggle/input/mias-mammography/all-mias/mdb110.pgm
# /kaggle/input/mias-mammography/all-mias/mdb242.pgm
# /kaggle/input/mias-mammography/all-mias/mdb181.pgm
# /kaggle/input/mias-mammography/all-mias/mdb214.pgm
# /kaggle/input/mias-mammography/all-mias/mdb099.pgm
# /kaggle/input/mias-mammography/all-mias/mdb005.pgm
# /kaggle/input/mias-mammography/all-mias/mdb155.pgm
# /kaggle/input/mias-mammography/all-mias/mdb015.pgm
# /kaggle/input/mias-mammography/all-mias/mdb034.pgm
# /kaggle/input/mias-mammography/all-mias/mdb208.pgm
# /kaggle/input/mias-mammography/all-mias/mdb293.pgm
# /kaggle/input/mias-mammography/all-mias/mdb244.pgm
# /kaggle/input/mias-mammography/all-mias/mdb203.pgm
# /kaggle/input/mias-mammography/all-mias/mdb210.pgm
# /kaggle/input/mias-mammography/all-mias/mdb121.pgm
# /kaggle/input/mias-mammography/all-mias/mdb075.pgm
# /kaggle/input/mias-mammography/all-mias/mdb111.pgm
# /kaggle/input/mias-mammography/all-mias/mdb228.pgm
# /kaggle/input/mias-mammography/all-mias/mdb130.pgm
# /kaggle/input/mias-mammography/all-mias/mdb291.pgm
# /kaggle/input/mias-mammography/all-mias/mdb216.pgm
# /kaggle/input/mias-mammography/all-mias/mdb140.pgm
# /kaggle/input/mias-mammography/all-mias/mdb285.pgm
# /kaggle/input/mias-mammography/all-mias/mdb263.pgm
# /kaggle/input/mias-mammography/all-mias/mdb212.pgm
# /kaggle/input/mias-mammography/all-mias/mdb049.pgm
# /kaggle/input/mias-mammography/all-mias/mdb016.pgm
# /kaggle/input/mias-mammography/all-mias/mdb151.pgm
# /kaggle/input/mias-mammography/all-mias/mdb171.pgm
# /kaggle/input/mias-mammography/all-mias/mdb283.pgm
# /kaggle/input/mias-mammography/all-mias/mdb080.pgm
# /kaggle/input/mias-mammography/all-mias/mdb279.pgm
# /kaggle/input/mias-mammography/all-mias/mdb028.pgm
# /kaggle/input/mias-mammography/all-mias/mdb081.pgm
# /kaggle/input/mias-mammography/all-mias/mdb267.pgm
# /kaggle/input/mias-mammography/all-mias/mdb227.pgm
# /kaggle/input/mias-mammography/all-mias/mdb290.pgm
# /kaggle/input/mias-mammography/all-mias/mdb163.pgm
# /kaggle/input/mias-mammography/all-mias/mdb226.pgm
# /kaggle/input/mias-mammography/all-mias/mdb117.pgm
# /kaggle/input/mias-mammography/all-mias/mdb274.pgm
# /kaggle/input/mias-mammography/all-mias/mdb215.pgm
# /kaggle/input/mias-mammography/all-mias/mdb310.pgm
# /kaggle/input/mias-mammography/all-mias/mdb139.pgm
# /kaggle/input/mias-mammography/all-mias/mdb231.pgm
# /kaggle/input/mias-mammography/all-mias/mdb054.pgm
# /kaggle/input/mias-mammography/all-mias/mdb322.pgm
# /kaggle/input/mias-mammography/all-mias/mdb129.pgm
# /kaggle/input/mias-mammography/all-mias/mdb159.pgm
# /kaggle/input/mias-mammography/all-mias/mdb289.pgm
# /kaggle/input/mias-mammography/all-mias/mdb149.pgm

# %% [markdown]
# ## Let's see how the dataset is composed

# %%
from PIL import Image
im = Image.open("../input/mias-mammography/all-mias/mdb001.pgm")
im
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=1024x1024 at 0x7F29BB03EE10>

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from IPython.display import clear_output
from tqdm.notebook import tqdm
import cv2
from sklearn.model_selection import train_test_split
import random

# %% [markdown]
# ## Data Load

# %%
imgs_path = '../input/mias-mammography/all-mias/'

# %% [markdown]
# ### Read Data Frame

# %%
print("Reading Dataframe")
info=pd.read_csv("../input/mias-mammography/Info.txt",sep=" ")
info=info.drop('Unnamed: 7',axis=1)
# Out:
# Reading Dataframe

# %%
info
# Out:
#      REFNUM BG CLASS SEVERITY      X      Y  RADIUS
# 0    mdb001  G  CIRC        B  535.0  425.0   197.0
# 1    mdb002  G  CIRC        B  522.0  280.0    69.0
# 2    mdb003  D  NORM      NaN    NaN    NaN     NaN
# 3    mdb004  D  NORM      NaN    NaN    NaN     NaN
# 4    mdb005  F  CIRC        B  477.0  133.0    30.0
# ..      ... ..   ...      ...    ...    ...     ...
# 325  mdb318  D  NORM      NaN    NaN    NaN     NaN
# 326  mdb319  D  NORM      NaN    NaN    NaN     NaN
# 327  mdb320  D  NORM      NaN    NaN    NaN     NaN
# 328  mdb321  D  NORM      NaN    NaN    NaN     NaN
# 329  mdb322  D  NORM      NaN    NaN    NaN     NaN
#
# [330 rows x 7 columns]

# %% [markdown]
# Let's save the Images ids

# %%
ids = {}
for i in range(len(info)):
    ids[i] = info.REFNUM[i]

# %% [markdown]
# Let's now create our labels for training

# %%
# Turning our outputs Normal-Abnormal to 0-1
label = []
for i in range(len(info)):
    if info.CLASS[i] != 'NORM':
        label.append(1)
    else:
        label.append(0)
label = np.array(label)
print(f"Cant. Imagenes: {len(label)}, Normales = {len(label)-np.sum(label)}, No normales= {np.sum(label)}")
# Out:
# Cant. Imagenes: 330, Normales = 207, No normales= 123

# %% [markdown]
# So we need to remove 84 normal breasts so the dataset is balanced

# %% [markdown]
# ### Importing our images

# %%
# define the every images filepaths in to list
img_name = []

for i in range(len(label)):
        img_name.append(imgs_path + info.REFNUM[i]+ '.pgm')

# %% [markdown]
# Removing 84 normal breasts

# %%
count = 0
remove = True
temp_label = []
temp_img_name = []

for i, lbl in enumerate(label.tolist()):
    if lbl == 0 and remove == True:
        count = count + 1
        if count >= 84:
            remove = False
    else:
        temp_label.append(lbl)
        temp_img_name.append(img_name[i])

# %%
label = np.array(temp_label)
img_name = temp_img_name

# %%
img_name = np.array(img_name)
img_name.shape
# Out:
# (246,)

# %%
#print(img_name)
print(f'image addres amount {img_name.shape}')
# Out:
# image addres amount (246,)

# %% [markdown]
# #### Let's see 25 random images of our dataset

# %%
# view image random images
def view_25_random_image():
    fig = plt.figure(figsize = (15, 10))
    for i in range(25):
        rand = random.randint(0,len(label))
        ax = plt.subplot(5, 5, i+1)
    
        img = cv2.imread(img_name[rand], 0)
        img = cv2.resize(img, (256,256))
        if label[rand] == 1:
            plt.title('Not Notmal')
        else:
            plt.title('Normal')
        plt.tight_layout()
        plt.axis('off')
        plt.imshow(img)
    fig.savefig('random_25_image_fig.png')

random_images = view_25_random_image()

# %% [markdown]
# #### Data Augmentation
#
# Since there are aproximately only 300 images, lets make some data augmentation by rotating the images

# %%
img_path = []
last_label = []
IMG_SIZE = 128

for i in range(len(img_name)):
    
    img = cv2.imread(img_name[i], 0)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
    rows, cols= img.shape
    for angle in range(180):
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle*2, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (IMG_SIZE, IMG_SIZE))
            img_path.append(img_rotated)
            if label[i] == 1:
                last_label.append(1)
            else:
                last_label.append(0)

# %%
img_path = np.array(img_path)
last_label = np.array(last_label)
img_path.shape
# Out:
# (44280, 128, 128)

# %%
img_path = img_path.reshape((-1,IMG_SIZE,IMG_SIZE,1))
img_path.shape
# Out:
# (44280, 128, 128, 1)

# %%
last_label.shape
# Out:
# (44280,)

# %% [markdown]
# Split our data for training and testing

# %%
# split train and test set
x_train, x_test, y_train, y_test = train_test_split(img_path, last_label, test_size = 0.2, random_state = 42)

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (35424, 8856, 35424, 8856)

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.activations import *
from keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from time import time

# %%
reg = tf.keras.regularizers.L2(l2=1e-5)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None)


model = Sequential()
model.add(Conv2D(32,
                 kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer = ini,
                 input_shape=(IMG_SIZE, IMG_SIZE, 1)))
model.add(Conv2D(64,
                 kernel_size=(3,3),
                 kernel_initializer = ini,
                 activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Conv2D(64, 
                 kernel_size=(3,3),
                 kernel_initializer = ini,
                 activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Dense(64, 
                kernel_initializer = ini,
                activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(
    learning_rate=1e-3)

model.compile(optimizer=optimizer,
              loss= 'binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 126, 126, 32)      320
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 124, 124, 64)      18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# dense_12 (Dense)             (None, 30, 30, 64)        4160
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 57601
# =================================================================
# Total params: 117,505
# Trainable params: 117,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=3,restore_best_weights=True, verbose=1)

check_point_filepath = './'

model_check_point = ModelCheckpoint(filepath =check_point_filepath, monitor='val_loss', verbose=1, save_best_only=True,
                                    save_weights_only=False, mode='auto', save_freq='epoch')

# %% [markdown]
# Let's train the Neural Network

# %%
train = True
if train:
    epochs=100
    history = model.fit(x_train,
                 y_train,
                 validation_split=0.2,
                 epochs=epochs,
                 batch_size=128,
                 callbacks=[early_stop, model_check_point])
else:
    model = tf.keras.models.load_model('./')
# Out:
# Epoch 1/100
# 222/222 [==============================] - 118s 528ms/step - loss: 0.6993 - accuracy: 0.5031 - val_loss: 0.6924 - val_accuracy: 0.5147
#
# Epoch 00001: val_loss improved from inf to 0.69240, saving model to ./
# Epoch 2/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6915 - accuracy: 0.5170 - val_loss: 0.6920 - val_accuracy: 0.5033
#
# Epoch 00002: val_loss improved from 0.69240 to 0.69196, saving model to ./
# Epoch 3/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6861 - accuracy: 0.5392 - val_loss: 0.6836 - val_accuracy: 0.5410
#
# Epoch 00003: val_loss improved from 0.69196 to 0.68362, saving model to ./
# Epoch 4/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6765 - accuracy: 0.5592 - val_loss: 0.6850 - val_accuracy: 0.5760
#
# Epoch 00004: val_loss did not improve from 0.68362
# Epoch 5/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6601 - accuracy: 0.5851 - val_loss: 0.6502 - val_accuracy: 0.5977
#
# Epoch 00005: val_loss improved from 0.68362 to 0.65018, saving model to ./
# Epoch 6/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6375 - accuracy: 0.6167 - val_loss: 0.6282 - val_accuracy: 0.6216
#
# Epoch 00006: val_loss improved from 0.65018 to 0.62821, saving model to ./
# Epoch 7/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.6126 - accuracy: 0.6375 - val_loss: 0.6057 - val_accuracy: 0.6423
#
# Epoch 00007: val_loss improved from 0.62821 to 0.60575, saving model to ./
# Epoch 8/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.5747 - accuracy: 0.6716 - val_loss: 0.5642 - val_accuracy: 0.6854
#
# Epoch 00008: val_loss improved from 0.60575 to 0.56418, saving model to ./
# Epoch 9/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.5370 - accuracy: 0.7036 - val_loss: 0.5326 - val_accuracy: 0.7190
#
# Epoch 00009: val_loss improved from 0.56418 to 0.53257, saving model to ./
# Epoch 10/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.4868 - accuracy: 0.7488 - val_loss: 0.4778 - val_accuracy: 0.7519
#
# Epoch 00010: val_loss improved from 0.53257 to 0.47777, saving model to ./
# Epoch 11/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.4338 - accuracy: 0.7847 - val_loss: 0.4358 - val_accuracy: 0.7853
#
# Epoch 00011: val_loss improved from 0.47777 to 0.43578, saving model to ./
# Epoch 12/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.3890 - accuracy: 0.8103 - val_loss: 0.4094 - val_accuracy: 0.8023
#
# Epoch 00012: val_loss improved from 0.43578 to 0.40940, saving model to ./
# Epoch 13/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.3513 - accuracy: 0.8349 - val_loss: 0.3762 - val_accuracy: 0.8251
#
# Epoch 00013: val_loss improved from 0.40940 to 0.37616, saving model to ./
# Epoch 14/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.3110 - accuracy: 0.8520 - val_loss: 0.3436 - val_accuracy: 0.8405
#
# Epoch 00014: val_loss improved from 0.37616 to 0.34364, saving model to ./
# Epoch 15/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.2862 - accuracy: 0.8703 - val_loss: 0.3270 - val_accuracy: 0.8536
#
# Epoch 00015: val_loss improved from 0.34364 to 0.32703, saving model to ./
# Epoch 16/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.2646 - accuracy: 0.8796 - val_loss: 0.2881 - val_accuracy: 0.8742
#
# Epoch 00016: val_loss improved from 0.32703 to 0.28807, saving model to ./
# Epoch 17/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.2365 - accuracy: 0.8953 - val_loss: 0.2705 - val_accuracy: 0.8847
#
# Epoch 00017: val_loss improved from 0.28807 to 0.27047, saving model to ./
# Epoch 18/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.2165 - accuracy: 0.9061 - val_loss: 0.2606 - val_accuracy: 0.8910
#
# Epoch 00018: val_loss improved from 0.27047 to 0.26059, saving model to ./
# Epoch 19/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1983 - accuracy: 0.9143 - val_loss: 0.2510 - val_accuracy: 0.8905
#
# Epoch 00019: val_loss improved from 0.26059 to 0.25102, saving model to ./
# Epoch 20/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1885 - accuracy: 0.9193 - val_loss: 0.2330 - val_accuracy: 0.9046
#
# Epoch 00020: val_loss improved from 0.25102 to 0.23295, saving model to ./
# Epoch 21/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1762 - accuracy: 0.9247 - val_loss: 0.2084 - val_accuracy: 0.9156
#
# Epoch 00021: val_loss improved from 0.23295 to 0.20838, saving model to ./
# Epoch 22/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1647 - accuracy: 0.9308 - val_loss: 0.1969 - val_accuracy: 0.9198
#
# Epoch 00022: val_loss improved from 0.20838 to 0.19687, saving model to ./
# Epoch 23/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1481 - accuracy: 0.9414 - val_loss: 0.1967 - val_accuracy: 0.9200
#
# Epoch 00023: val_loss improved from 0.19687 to 0.19666, saving model to ./
# Epoch 24/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1426 - accuracy: 0.9429 - val_loss: 0.1884 - val_accuracy: 0.9282
#
# Epoch 00024: val_loss improved from 0.19666 to 0.18835, saving model to ./
# Epoch 25/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1375 - accuracy: 0.9457 - val_loss: 0.1719 - val_accuracy: 0.9339
#
# Epoch 00025: val_loss improved from 0.18835 to 0.17186, saving model to ./
# Epoch 26/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1261 - accuracy: 0.9509 - val_loss: 0.1717 - val_accuracy: 0.9332
#
# Epoch 00026: val_loss improved from 0.17186 to 0.17169, saving model to ./
# Epoch 27/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1238 - accuracy: 0.9503 - val_loss: 0.1689 - val_accuracy: 0.9363
#
# Epoch 00027: val_loss improved from 0.17169 to 0.16892, saving model to ./
# Epoch 28/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1211 - accuracy: 0.9528 - val_loss: 0.1518 - val_accuracy: 0.9447
#
# Epoch 00028: val_loss improved from 0.16892 to 0.15176, saving model to ./
# Epoch 29/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1007 - accuracy: 0.9618 - val_loss: 0.1570 - val_accuracy: 0.9407
#
# Epoch 00029: val_loss did not improve from 0.15176
# Epoch 30/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1020 - accuracy: 0.9608 - val_loss: 0.1543 - val_accuracy: 0.9430
#
# Epoch 00030: val_loss did not improve from 0.15176
# Epoch 31/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.1470 - val_accuracy: 0.9489
#
# Epoch 00031: val_loss improved from 0.15176 to 0.14700, saving model to ./
# Epoch 32/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.1003 - accuracy: 0.9636 - val_loss: 0.1409 - val_accuracy: 0.9489
#
# Epoch 00032: val_loss improved from 0.14700 to 0.14085, saving model to ./
# Epoch 33/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0887 - accuracy: 0.9661 - val_loss: 0.1377 - val_accuracy: 0.9527
#
# Epoch 00033: val_loss improved from 0.14085 to 0.13766, saving model to ./
# Epoch 34/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0871 - accuracy: 0.9685 - val_loss: 0.1295 - val_accuracy: 0.9537
#
# Epoch 00034: val_loss improved from 0.13766 to 0.12953, saving model to ./
# Epoch 35/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0852 - accuracy: 0.9698 - val_loss: 0.1461 - val_accuracy: 0.9499
#
# Epoch 00035: val_loss did not improve from 0.12953
# Epoch 36/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0835 - accuracy: 0.9691 - val_loss: 0.1294 - val_accuracy: 0.9537
#
# Epoch 00036: val_loss improved from 0.12953 to 0.12943, saving model to ./
# Epoch 37/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0868 - accuracy: 0.9685 - val_loss: 0.1123 - val_accuracy: 0.9596
#
# Epoch 00037: val_loss improved from 0.12943 to 0.11230, saving model to ./
# Epoch 38/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0743 - accuracy: 0.9734 - val_loss: 0.1193 - val_accuracy: 0.9599
#
# Epoch 00038: val_loss did not improve from 0.11230
# Epoch 39/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0787 - accuracy: 0.9703 - val_loss: 0.1403 - val_accuracy: 0.9476
#
# Epoch 00039: val_loss did not improve from 0.11230
# Epoch 40/100
# 222/222 [==============================] - 117s 527ms/step - loss: 0.0794 - accuracy: 0.9721 - val_loss: 0.1181 - val_accuracy: 0.9613
# Restoring model weights from the end of the best epoch.
#
# Epoch 00040: val_loss did not improve from 0.11230
# Epoch 00040: early stopping

# %% [markdown]
# Let's See one result

# %%
from random import randint
test_num = randint(0,len(x_test))
#test_num = 274
result = model.predict(np.array([x_test[test_num]]))

plt.figure(figsize= (10,10))
plt.imshow(x_test[test_num])

print(f"The results was: {result[0][0]>= 0.5}       And the probability being: {result[0][0]}\nReal value was: {y_test[test_num]>=0.5}")
print(f"Test id: {test_num}")
# Out:
# The results was: False       And the probability being: 1.7425828673367505e-06
# Real value was: False
# Test id: 2757

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Plots

# %%
plt.figure(figsize=(10,5))
plt.plot(range(len(history.history['accuracy'])),history.history['accuracy'], label= "accuracy")
plt.plot(range(0,len(history.history['val_accuracy'])),history.history['val_accuracy'], label= "val_accuracy")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epoch")
plt.legend()
plt.show()

# %% [markdown]
# It is likely possible that the model is overfitting or the images aren't a good way to determinig if a breast has cancer or not.

# %%
plt.figure(figsize=(10,5))
plt.plot(range(0,len(history.history['loss'])),history.history['loss'], label= "loss")
plt.plot(range(0,len(history.history['val_loss'])),history.history['val_loss'], label= "val_loss")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on the hole Test Data

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 277/277 - 28s - loss: 0.1166 - accuracy: 0.9601
#
# Test accuracy: 0.9601399898529053

# %% [markdown]
# Save the model

# %%
len(x_test)
# Out:
# 8856

# %%
save_model = True
if save_model:
    save_model_path = "./"
    model.save(save_model_path)
